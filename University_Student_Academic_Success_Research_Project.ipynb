# %% [markdown]
# <a href="https://colab.research.google.com/github/Jonah-Banks-Menchukov/University-Student-Academic-Success-Research-Project/blob/main/University_Student_Academic_Success_Research_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imports and first day analysis

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
df=pd.read_csv('https://raw.githubusercontent.com/frontiertechinstitute/datasets/refs/heads/main/University%20Student%20Academic%20Success%20Dataset/university_student_academic_success_dataset.csv',sep=';')

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
mo_list=df["Mother's occupation"].to_numpy()
fo_list=df["Father's occupation"].to_numpy()
mq_list=df["Mother's qualification"].to_numpy()
fq_list=df["Father's qualification"].to_numpy()
umo_list=df["Mother's occupation"].unique()
ufo_list=df["Father's occupation"].unique()
umq_list=df["Mother's qualification"].unique()
ufq_list=df["Father's qualification"].unique()
t_list=df['Target'].to_numpy()
gfo_list=np.zeros(len(ufo_list),dtype=int)
efo_list=np.zeros(len(ufo_list),dtype=int)
dfo_list=np.zeros(len(ufo_list),dtype=int)
gmo_list=np.zeros(len(umo_list),dtype=int)
emo_list=np.zeros(len(umo_list),dtype=int)
dmo_list=np.zeros(len(umo_list),dtype=int)
gfq_list=np.zeros(len(ufq_list),dtype=int)
efq_list=np.zeros(len(ufq_list),dtype=int)
dfq_list=np.zeros(len(ufq_list),dtype=int)
gmq_list=np.zeros(len(umq_list),dtype=int)
emq_list=np.zeros(len(umq_list),dtype=int)
dmq_list=np.zeros(len(umq_list),dtype=int)
for i in range(0,len(fo_list)):
  for j in range(0,len(ufo_list)):
    if (t_list[i]=='Graduate' and ufo_list[j]==fo_list[i]):
      gfo_list[j]=gfo_list[j]+1
    elif(t_list[i]=='Enrolled' and ufo_list[j]==fo_list[i]):
      efo_list[j]+=1
    elif(t_list[i]=='Dropout' and ufo_list[j]==fo_list[i]):
      dfo_list[j]+=1
for i in range(0,len(mo_list)):
  for j in range(0,len(umo_list)):
    if (t_list[i]=='Graduate' and umo_list[j]==mo_list[i]):
      gmo_list[j]=gmo_list[j]+1
    elif(t_list[i]=='Enrolled' and umo_list[j]==mo_list[i]):
      emo_list[j]+=1
    elif(t_list[i]=='Dropout' and umo_list[j]==mo_list[i]):
      dmo_list[j]+=1
for i in range(0,len(fq_list)):
  for j in range(0,len(ufq_list)):
    if (t_list[i]=='Graduate' and ufq_list[j]==fq_list[i]):
      gfq_list[j]=gfq_list[j]+1
    elif(t_list[i]=='Enrolled' and ufq_list[j]==fq_list[i]):
      efq_list[j]+=1
    elif(t_list[i]=='Dropout' and ufq_list[j]==fq_list[i]):
      dfq_list[j]+=1
for i in range(0,len(mq_list)):
  for j in range(0,len(umq_list)):
    if (t_list[i]=='Graduate' and umq_list[j]==mq_list[i]):
      gmq_list[j]=gmq_list[j]+1
    elif(t_list[i]=='Enrolled' and umq_list[j]==mq_list[i]):
      emq_list[j]+=1
    elif(t_list[i]=='Dropout' and umq_list[j]==mq_list[i]):
      dmq_list[j]+=1

# %%
medus=df["Mother's qualification"].to_numpy()
fedus=df["Father's qualification"].to_numpy()
edu_Levels=[]
g_targets=df['Target'].to_numpy()
for i in range (0,len(medus)):
  if(medus[i] == 2 or medus[i]==3 or medus[i]==4 or medus[i]==5 or medus[i]==6 or medus[i]==40 or medus[i]==41 or medus[i]==42 or medus[i]==43 or medus[i]==44):
    edu_Levels.append(2)
  elif(fedus[i] == 2 or fedus[i]==3 or fedus[i]==4 or fedus[i]==5 or fedus[i]==6 or fedus[i]==40 or fedus[i]==41 or fedus[i]==42 or fedus[i]==43 or fedus[i]==44):
    edu_Levels.append(1)
  else:
    edu_Levels.append(0)
df['EduLevels']=edu_Levels

# %%
graduates=df[df['Target']=='Graduate']
dropouts=df[df['Target']=='Dropout']
enrolled=df[df['Target']=='Enrolled']

# %%
#list formulation: no hs, hs , college
g=np.zeros(3)
e=np.zeros(3)
d=np.zeros(3)
ocs=['No HS/ career alternative','HS/ Career alternative','College or equiv']
g_targets=df['Target']
for i in range (0,len(fq_list)):
  if(fq_list[i] == 2 or fq_list[i]==3 or fq_list[i]==4 or fq_list[i]==5 or fq_list[i]==6 or fq_list[i]==40 or fq_list[i]==41 or fq_list[i]==42 or fq_list[i]==43 or fq_list[i]==44 or mq_list[i] == 2 or mq_list[i]==3 or mq_list[i]==4 or mq_list[i]==5 or mq_list[i]==6 or mq_list[i]==40 or mq_list[i]==41 or mq_list[i]==42 or mq_list[i]==43 or mq_list[i]==44):
    if(g_targets[i]=='Graduate'):
      g[2]+=1
    elif(g_targets[i]=='Enrolled'):
      e[2]+=1
    else:
      d[2]+=1
  elif(fq_list[i]==1 or fq_list[i]==39 or fq_list[i]==9 or fq_list[i]==10 or fq_list[i]==11 or fq_list[i]==12 or fq_list[i]==13 or fq_list[i]==14 or fq_list[i]==18 or fq_list[i]== 19 or fq_list[i] ==20 or fq_list[i] ==22 or fq_list[i]== 25 or mq_list[i]==1 or mq_list[i]==39 or mq_list[i]==9 or mq_list[i]==10 or fedus[i]==11 or mq_list[i]==12 or mq_list[i]==13 or mq_list[i]==14 or mq_list[i]==18 or mq_list[i]== 19 or mq_list[i] ==20 or mq_list[i] ==22 or mq_list[i]== 25 ):
    if(g_targets[i]=='Graduate'):
      g[1]+=1
    elif(g_targets[i]=='Enrolled'):
      e[1]+=1
    else:
      d[1]+=1
  else:
    if(g_targets[i]=='Graduate'):
      g[0]+=1
    elif(g_targets[i]=='Enrolled'):
      e[0]+=1
    else:
      d[0]+=1

# %%
for i in range(0,len(ufo_list)):
  gfo_list[i]

# %%
import matplotlib.pyplot as plt
import numpy as np

# data from https://allisonhorst.github.io/palmerpenguins/


targets = {
    "Dropout": dfo_list,
    "Enrolled": efo_list,
    "Graduate":gfo_list
}
width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(len(ufo_list))

for boolean, targets in targets.items():
    p = ax.bar(ufo_list, targets, width, label=boolean, bottom=bottom)
    bottom += targets

ax.set_title("Graduation rate of students by Father's occupation")
ax.legend(loc="upper right")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# data from https://allisonhorst.github.io/palmerpenguins/


targets = {
    "Dropout":dmo_list,
    "Enrolled":emo_list,
    "Graduate":gmo_list
}
width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(len(umo_list))

for boolean, targets in targets.items():
    p = ax.bar(umo_list, targets, width, label=boolean, bottom=bottom)
    bottom += targets

ax.set_title("Graduation rate of students by Mother's occupation")
ax.legend(loc="upper right")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# data from https://allisonhorst.github.io/palmerpenguins/


targets = {
    "Dropout":dfq_list,
    "Enrolled":efq_list,
    "Graduate":gfq_list
}
width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(len(ufq_list))

for boolean, targets in targets.items():
    p = ax.bar(ufq_list, targets, width, label=boolean, bottom=bottom)
    bottom += targets

ax.set_title("Graduation rate of students by Father's qualification")
ax.legend(loc="upper right")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# data from https://allisonhorst.github.io/palmerpenguins/


targets = {
    "Dropout":dmq_list,
    "Enrolled":emq_list,
    "Graduate":gmq_list
}
width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(len(umq_list))

for boolean, targets in targets.items():
    p = ax.bar(umq_list, targets, width, label=boolean, bottom=bottom)
    bottom += targets

ax.set_title("Graduation rate of students by Mother's qualification")
ax.legend(loc="upper right")

plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
#find which career cluster/qualification level has the greatest ratio of graduation to other results
foi=0
fop=0
moi=0
mop=0
fqi=0
fqp=0
mqi=0
mqp=0
for i in range(0,len(gfo_list)):
  pct=gfo_list[i]/(gfo_list[i]+efo_list[i]+dfo_list[i])
  if pct>fop and gfo_list[i]>25:
    fop=pct
    foi=i
for i in range(0,len(gmo_list)):
  pct=gmo_list[i]/(gmo_list[i]+emo_list[i]+dmo_list[i])
  if pct>mop and gmo_list[i]>25:
    mop=pct
    moi=i
for i in range(0,len(gfq_list)):
  pct=gfq_list[i]/(gfq_list[i]+efq_list[i]+dfq_list[i])
  if pct>fqp and fq_list[i]>25:
    fqp=pct
    fqi=i
for i in range(0,len(gmq_list)):
  pct=gmq_list[i]/(gmq_list[i]+emq_list[i]+dmq_list[i])
  if pct>mqp and mq_list[i]>25:
    mqp=pct
    mqi=i
print(f"Father's occ: {ufo_list[foi]}",f"Mother's occ: {umo_list[moi]}",
      f"Father's qual: {ufq_list[fqi]}",f"Mother's qual: {umq_list[mqi]}",sep="\n")
# Out:
# Father's occ: 7
# Mother's occ: 6
# Father's qual: 43
# Mother's qual: 38

# %%
import matplotlib.pyplot as plt
import numpy as np

edu_levels=(
    'no hs/college',
    'hs/career education',
    'college',
)
targets = {
    "dropout": np.array(d),
    "enrolled": np.array(e),
    "graduate": np.array(g),
}

width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(3)

for boolean, targets in targets.items():
    p = ax.bar(edu_levels, targets, width, label=boolean, bottom=bottom)
    bottom += targets

ax.set_title("Graduation rate of students by parental education")
ax.legend(loc="upper right")

plt.show()

# %%
df['EduLevels']=edu_Levels

# %%
import scipy.stats as stats
print(stats.chi2_contingency(pd.crosstab(df['Target'],df["Gender"])).pvalue)
# Out:
# 2.2224795668092454e-51

# %%
['Displaced']
# Out:
# ['Displaced']

# %%
import sklearn
from sklearn import model_selection

# %%
X_train,X_test,y_train,y_test=model_selection.train_test_split(df[["Gender","Curricular units 1st sem (grade)","Curricular units 2nd sem (grade)","Previous qualification (grade)","Mother's qualification","Father's qualification"]],df["Target"],test_size=0.2,train_size=0.8,random_state=40)

# %%
X_train,X_test,y_train,y_test=model_selection.train_test_split(df[["Gender","Curricular units 1st sem (grade)","Curricular units 2nd sem (grade)","Previous qualification (grade)"]],df["Target"],test_size=0.2,train_size=0.8,random_state=40)

# %%
cols=df.drop(columns=['Target']).columns
for i in range(0,len(cols)):
  print(cols[i])
  if (df[cols[i]].dtype=='float64'):
    print(stats.f_oneway(graduates[cols[i]],enrolled[cols[i]],dropouts[cols[i]]).pvalue)
    print(stats.tukey_hsd(graduates[cols[i]],enrolled[cols[i]],dropouts[cols[i]]).pvalue)
  elif(df[cols[i]].dtype=='int64'):
    print('pvalue=',stats.chi2_contingency(pd.crosstab(df[cols[i]],df['Target'])).pvalue,sep='')
# Out:
# Marital status
# pvalue=8.054279703889306e-10
# Application mode
# pvalue=1.9646567814647118e-77
# Application order
# pvalue=2.272034830371239e-09
# Course
# pvalue=2.3165709040666167e-97
# Daytime/evening attendance
# pvalue=5.743834299642735e-07
# Previous qualification
# pvalue=7.160305160682533e-30
# Previous qualification (grade)
# 1.0777825583187265e-12
# [[1.00000000e+00 3.66107759e-07 9.20784560e-11]
#  [3.66107759e-07 1.00000000e+00 9.85554991e-01]
#  [9.20784560e-11 9.85554991e-01 1.00000000e+00]]
# Nacionality
# pvalue=0.24222552059446276
# Mother's qualification
# pvalue=5.823844464375137e-21
# Father's qualification
# pvalue=3.175006994347662e-19
# Mother's occupation
# pvalue=1.63085860350197e-31
# Father's occupation
# pvalue=4.51543856251902e-19
# Admission grade
# 4.380466113389808e-16
# [[1.00000000e+00 1.32279716e-07 0.00000000e+00]
#  [1.32279716e-07 1.00000000e+00 6.40462422e-01]
#  [0.00000000e+00 6.40462422e-01 1.00000000e+00]]
# Displaced
# ...

# %%
model.fit(X_train,y_train)
x_validate,x_test,y_validate,y_test=model_selection.train_test_split(X_test,y_test,random_state=42)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
pred=model.predict(x_validate)
print(metrics.accuracy_score(y_true=y_validate,y_pred=pred))
# Out:
# 0.6440422322775264

# %%
from sklearn.neighbors import KNeighborsClassifier
model2=KNeighborsClassifier(n_neighbors=5)
model2.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
pred2=model2.predict(x_validate)
print(metrics.accuracy_score(y_true=y_validate,y_pred=pred2))
# Out:
# 0.6153846153846154

# %%
import matplotlib.pyplot as plt
import numpy as np

# data from https://allisonhorst.github.io/palmerpenguins/


targets = {
    "dropouts":[len(dropouts[dropouts['Gender']==0].index),len(dropouts[dropouts['Gender']==1].index)],
    "enrolled":[len(enrolled[enrolled['Gender']==0].index),len(enrolled[enrolled['Gender']==1].index)],
    "graduates":[len(graduates[graduates['Gender']==0].index),len(graduates[graduates['Gender']==1].index)],
}
width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(2)

for boolean, targets in targets.items():
    p = ax.bar(['female','male'], targets, width, label=boolean, bottom=bottom)
    bottom += targets

ax.set_title("Graduation rate of students by Gender")
ax.legend(loc="upper right")

plt.show()

# %%
from sklearn import metrics
metrics.ConfusionMatrixDisplay.from_predictions(y_validate,pred,display_labels=['dropout','enrolled','graduate'])
plt.show()

# %%
pred=model.predict(x_test)
print(metrics.con)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_733/1575907947.py in <cell line: 0>()
# ----> 1 model.predict(test)
#
# NameError: name 'test' is not defined
